# %%
# Load libraries
import seaborn
import pandas
from sklearn import tree
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_validate
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import graphviz
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report, f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
#Load Dataset from CSV file
dataset = pandas.read_csv("../unplugged.csv")
dataset.sample(frac=1)
dataset = dataset[0:360]
del dataset['Comments']

# %%
print(dataset.head(300))
# Out:
#      School Name           Student Name  Age Gender Results_Before  \
# 0      IMSJ G9-2                 Anthny   12      M              F
# 1      IMSJ G9-2            Farhana Ali   10      F              F
# 2      IMSJ G9-2              Samiullah   10      M              F
# 3      IMSJ G9-2                  Uzair   12      M              F
# 4      IMSJ G9-2                  Sarim    8      M              P
# 5      IMSJ G9-2              M. Sohaib   12      M              F
# 6      IMSJ G9-2                  Laiba    8      F              F
# 7      IMSJ G9-2              Isha Khan    9      F              F
# 8      IMSJ G9-2            Ayesha Ayaz    9      F              F
# 9      IMSJ G9-2           Rubab Khalid   10      F              F
# 10     IMSJ G9-2            Umme Habiba   10      F              F
# 11     IMSJ G9-2            Hifza Qasar   10      F              F
# 12     IMSJ G9-2            Fariha Noor    9      F              P
# 13           NaN        Samawia Shakeel   11      F              F
# 14           NaN              Huma Gull   12      F              F
# 15           NaN          Nawera Masood   10      F              F
# 16           NaN           Eman Mehboob    9      F              F
# 17           NaN                   Urwa   10      F              P
# 18           NaN          Zarish Arshad   10      F              F
# 19           NaN           Nimra Abbasi   10      F              F
# 20           NaN             Sana Majid   12      F              P
# 21           NaN        Muneeba Mehmood   12      F              P
# 22           NaN           Insha Kanwal   11      F              F
# 23           NaN            Ayesha Wali   10      F              F
# 24           NaN            Fiza Waseem   11      F              F
# 25           NaN           Ruqayya Noor   11      F              F
# 26           NaN           Hadia Shaban   10      F              F
# 27           NaN                  Daran   11      F              P
# 28           NaN           Aliza Rizwan   10      F              F
# 29           NaN           Huma Shahzad   11      F              P
# ..           ...                    ...  ...    ...            ...
# 270  IMCG G-10/2            Aleeza Iman    9      F              F
# 271  IMCG G-10/2                  Yumna    9      F              F
# 272  IMCG G-10/2            Abrish Noor   10      F              P
# 273  IMCG G-10/2                 Alisha    9      F              P
# 274  IMCG G-10/2                Qandeel    9      F              P
# 275  IMCG G-10/2                 Adeena    8      F              P
# 276  IMCG G-10/2                Mahnoor    9      F              P
# 277  IMCG G-10/2                Manahil    8      F              F
# 278  IMCG G-10/2                 Sufera    8      F              P
# 279  IMCG G-10/2                  Momal    9      F              P
# 280  IMCG G-10/2             Summan naz    9      F              P
# 281  IMCG G-10/2                  Saman    9      F              F
# 282  IMCG G-10/2                 Ayesha    7      F              P
# 283  IMCG G-10/2                Mahnoor    8      F              P
# 284  IMCG G-10/2                  Sadia    9      F              P
# 285  IMCG G-10/2                  Shiza    9      F              F
# 286  IMCG G-10/2           Hadiya Jamil   10      F              F
# 287  IMCG G-10/2         Tanzeer Imtiaz    9      F              P
# 288  IMCG G-10/2            Fatima aziz    9      F              F
# 289  IMCG G-10/2            Hira Mazhar    9      F              P
# 290  IMCG G-10/2         Rabiya Mushtaq    9      F              F
# 291  IMCG G-10/2  khadija Muhammad Khan   10      F              P
# 292  IMCG G-10/2           Eman Maqbool   10      F              F
# 293  IMCG G-10/2                  Hamna    9      F              P
# 294  IMCG G-10/2                 Hooria   10      F              P
# 295  IMCG G-10/2             Dua khalid    8      F              P
# 296  IMCG G-10/2             Niha Malik    8      F              F
# 297  IMCG G-10/2           Aniza Farhat    9      F              F
# 298  IMCG G-10/2          Ayesha batool    9      F              F
# 299  IMCG G-10/2            Aimen Siyam    9      F              P
#
#     Results_After  Class Change Positive Outcomes
# 0               F      4      F                 F
# 1               F      4      F                 F
# 2               F      4      F                 F
# 3               F      4      F                 F
# 4               P      4      T                 F
# 5               P      4      T                 T
# 6               P      4      T                 T
# 7               F      4      F                 F
# 8               P      4      T                 T
# 9               P      4      T                 T
# 10              P      4      T                 T
# 11              F      4      F                 F
# 12              P      4      T                 F
# 13              P      5      T                 T
# 14              P      5      T                 T
# 15              P      5      T                 T
# 16              P      5      T                 T
# 17              P      5      T                 F
# 18              P      5      T                 T
# 19              P      5      T                 T
# 20              P      5      T                 F
# 21              P      5      T                 F
# 22              P      5      T                 T
# 23              P      5      T                 T
# 24              P      5      T                 T
# 25              P      5      T                 T
# 26              P      5      T                 T
# 27              F      5      F                 F
# 28              P      5      T                 T
# 29              P      5      T                 F
# ..            ...    ...    ...               ...
# 270             P      4      T                 T
# 271             F      4      F                 F
# 272             F      4      F                 F
# 273             F      4      F                 F
# 274             F      4      F                 F
# 275             P      4      T                 F
# 276             P      4      T                 F
# 277             F      4      F                 F
# 278             P      4      T                 F
# 279             P      4      T                 F
# 280             P      4      T                 F
# 281             P      4      T                 T
# 282             P      4      T                 F
# 283             P      4      T                 F
# 284             P      4      T                 F
# 285             F      4      F                 F
# 286             F      4      F                 F
# 287             P      4      T                 F
# 288             P      4      T                 T
# 289             P      4      T                 F
# 290             F      4      F                 F
# 291             P      4      T                 F
# 292             P      4      T                 T
# 293             P      4      T                 F
# 294             P      4      T                 F
# 295             P      4      T                 F
# 296             P      4      T                 T
# 297             F      4      F                 F
# 298             P      4      T                 T
# 299             P      4      T                 F
#
# [300 rows x 9 columns]

# %%
print(dataset.shape)
# Out:
# (360, 9)

# %%
# Assign int values to string
gender = {'M': 1, 'F': 2}
dataset.Gender = [gender[item] for item in dataset.Gender]

before = {'F': 0, 'P': 1}
dataset.Results_Before   = [before[item] for item in dataset.Results_Before]


print(dataset.describe())

dataset =  dataset[['Age', 'Gender', 'Class', 'Results_Before', 'Results_After']]
# Out:
#               Age      Gender  Results_Before       Class
# count  360.000000  360.000000      360.000000  360.000000
# mean     9.616667    1.630556        0.391667    4.052778
# std      1.287502    0.483326        0.488802    0.619995
# min      7.000000    1.000000        0.000000    3.000000
# 25%      9.000000    1.000000        0.000000    4.000000
# 50%     10.000000    2.000000        0.000000    4.000000
# 75%     10.000000    2.000000        1.000000    4.000000
# max     14.000000    2.000000        1.000000    5.000000

# %%
# print(dataset.head(300))

# %%
dataset.hist()
plt.show()

# %%
from sklearn.model_selection import train_test_split
array = dataset.values
X = array[:,0:4]
Y = array[:,4:]
test_size = 0.2
seed = 7
#Split dataset into 80-20 ratio
#80% train data, 20% test data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=test_size, 
random_state=seed, stratify = dataset['Results_After'])

# %%
# Test options and evaluation metric
num_folds = 10
num_instances = len(X_train)
seed = 7
scoring = 'accuracy'
models = []

models.append(('DT', DecisionTreeClassifier()))

# evaluate each model in turn
results = []
names = []

# %%
#Apply K-Fold for cross checking the Model accuracy
import sklearn
for name, model in models:
	kfold = sklearn.model_selection.KFold(n_splits=10,shuffle=True, random_state=5)
	cv_results = sklearn.model_selection.cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# Out:
# DT: 0.736084 (0.099185)

# %%
clf = DecisionTreeClassifier()
#Train our model
clf.fit(X_train, Y_train)
#Predict using our trained model
predictions = clf.predict(X_test)
#Find Accuracy
print(str(accuracy_score(Y_test, predictions)*100)+'%')
# Out:
# 76.38888888888889%

# %%
testy = []
probsy = [] 
probs = predictions[:]
for i in range(len(probs)):
    if (probs[i] == 'F'):
        probsy.append(0)
    else:
        probsy.append(1)
#     print(i)
for i in range(len(Y_test)):
    if (Y_test[i][0] == 'F'):
        testy.append(0)
    else:
        testy.append(1)
#     print (i)
# calculate AUC
auc = roc_auc_score(testy, probsy)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(testy, probsy)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.602

# %%
print(confusion_matrix(Y_test, predictions))
# Out:
# [[ 5 13]
#  [ 4 50]]

# %%
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            F       0.56      0.28      0.37        18
#            P       0.79      0.93      0.85        54
#
#    micro avg       0.76      0.76      0.76        72
#    macro avg       0.67      0.60      0.61        72
# weighted avg       0.73      0.76      0.73        72

# %%
# Plot the Decision Tree
dot_data = tree.export_graphviz(clf, out_file=None,
#                      feature_names=vectorizer.get_feature_names(),
                     class_names=["0", "1"],
                     filled=True, rounded=True,
                     special_characters=True)

dot_data = tree.export_graphviz(clf, out_file=None)
graph = graphviz.Source(dot_data)
graph.render("RanderedDT_After")
graph

# %% [markdown]
# # Random Dataset

# %%
#Load the random dataset
dataset = pandas.read_csv("../random_dataset.csv")
dataset.sample(frac=1)
# Out:
#       Age Gender Results_Before Results_After  Class Positive Outcomes
# 2855   12      M              P             P      4                 F
# 319    13      M              F             P      4                 T
# 3996   12      F              P             P      5                 F
# 3549   11      M              F             F      3                 F
# 2921    9      F              P             P      4                 F
# 3605   11      F              F             F      3                 F
# 492    10      F              F             F      3                 F
# 4295   12      F              F             P      4                 T
# 4773    8      M              F             F      4                 F
# 4317   14      F              P             P      5                 F
# 2279   10      M              P             F      5                 F
# 801    14      M              P             P      4                 F
# 2477    9      M              P             F      4                 F
# 2698    9      M              P             F      4                 F
# 3780    7      F              F             F      5                 F
# 465     9      F              P             P      5                 F
# 1466   11      F              F             P      4                 T
# 488    14      M              P             F      3                 F
# 1183    9      F              P             F      4                 F
# 956     9      M              P             F      5                 F
# 388    13      M              F             F      3                 F
# 3567    7      M              F             P      5                 T
# 4543   10      M              F             F      3                 F
# 44     12      F              F             F      3                 F
# 4465    7      F              P             F      5                 F
# 1713   10      F              P             P      3                 F
# 3956    7      F              P             F      5                 F
# 2817    7      M              P             F      5                 F
# 4068   10      M              P             P      4                 F
# 2769    7      F              F             F      4                 F
# ...   ...    ...            ...           ...    ...               ...
# 1313   14      M              F             F      5                 F
# 4713   12      F              F             F      5                 F
# 1193    8      F              F             F      4                 F
# 624    11      F              P             F      5                 F
# 115    13      F              F             P      5                 T
# 241    14      F              P             P      5                 F
# 817     9      F              P             P      4                 F
# 3864    9      M              P             P      4                 F
# 2819   10      M              P             P      4                 F
# 1612   14      F              P             P      5                 F
# 3312   13      F              F             P      4                 T
# 4139   11      F              P             F      3                 F
# 139    13      M              F             F      3                 F
# 573     9      M              F             P      4                 T
# 3295   13      F              P             F      5                 F
# 874     9      F              P             F      4                 F
# 88     14      F              F             F      5                 F
# 3066   12      M              P             F      3                 F
# 3176   12      M              F             P      3                 T
# 1467   14      F              F             F      5                 F
# 4468    8      F              P             P      3                 F
# 473     9      F              F             F      5                 F
# 1269   11      F              P             P      3                 F
# 3735   10      M              P             F      5                 F
# 3746   14      M              F             F      4                 F
# 769     8      M              P             P      4                 F
# 4052    8      M              P             F      5                 F
# 2316   13      F              P             F      5                 F
# 2749    8      M              P             P      4                 F
# 2580   10      F              P             P      3                 F
#
# [5000 rows x 6 columns]

# %%
print(dataset.head(10))
# Out:
#    Age Gender Results_Before Results_After  Class Positive Outcomes
# 0   12      F              P             P      4                 F
# 1   11      M              F             P      5                 T
# 2   11      M              F             P      3                 T
# 3   14      F              P             P      4                 F
# 4   14      M              P             F      3                 F
# 5   14      F              F             P      4                 T
# 6    9      F              P             F      3                 F
# 7   11      F              F             P      5                 T
# 8   12      F              F             F      4                 F
# 9   12      M              P             P      4                 F

# %%
# Assign int values to string   
gender = {'M': 1, 'F': 2}
dataset.Gender = [gender[item] for item in dataset.Gender]

before = {'F': 0, 'P': 1}
dataset.Results_Before   = [before[item] for item in dataset.Results_Before]


print(dataset.describe())

dataset =  dataset[['Age', 'Gender', 'Class', 'Results_Before', 'Results_After']]
# Out:
#                Age       Gender  Results_Before        Class
# count  5000.000000  5000.000000     5000.000000  5000.000000
# mean     10.493400     1.492000        0.493600     4.017800
# std       2.280394     0.499986        0.500009     0.817323
# min       7.000000     1.000000        0.000000     3.000000
# 25%       9.000000     1.000000        0.000000     3.000000
# 50%      10.000000     1.000000        0.000000     4.000000
# 75%      12.000000     2.000000        1.000000     5.000000
# max      14.000000     2.000000        1.000000     5.000000

# %%
dataset.hist()
plt.show()

# %%
#Split dataset into train and test dataset
from sklearn.model_selection import train_test_split
array = dataset.values
X = array[:,0:4]
Y = array[:,4:]
test_size = 0.2
seed = 7
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=test_size, 
random_state=seed, stratify = dataset['Results_After'])

# %%
# Test options and evaluation metric
num_folds = 10
num_instances = len(X_train)
seed = 7
scoring = 'accuracy'
models = []

models.append(('DT', DecisionTreeClassifier()))

# evaluate each model in turn
results = []
names = []

# %%
#Apply K fold, cross checking the accuracy of our model
import sklearn
for name, model in models:
	kfold = sklearn.model_selection.KFold(n_splits=10,shuffle=True, random_state=5)
	cv_results = sklearn.model_selection.cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# Out:
# DT: 0.497250 (0.013622)

# %%
#Train the Model
clf = DecisionTreeClassifier()
clf.fit(X_train, Y_train)
# Make predictions using our trained Model
predictions = clf.predict(X_test)
#Find accuracy
print(str(accuracy_score(Y_test, predictions)*100)+'%')
# Out:
# 46.6%

# %%
testy = []
probsy = [] 
probs = predictions[:]
for i in range(len(probs)):
    if (probs[i] == 'F'):
        probsy.append(0)
    else:
        probsy.append(1)
#     print(i)
for i in range(len(Y_test)):
    if (Y_test[i][0] == 'F'):
        testy.append(0)
    else:
        testy.append(1)
#     print (i)
# calculate AUC
auc = roc_auc_score(testy, probsy)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(testy, probsy)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.465

# %%
print(confusion_matrix(Y_test, predictions))
# Out:
# [[275 229]
#  [305 191]]

# %%
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            F       0.47      0.55      0.51       504
#            P       0.45      0.39      0.42       496
#
#    micro avg       0.47      0.47      0.47      1000
#    macro avg       0.46      0.47      0.46      1000
# weighted avg       0.46      0.47      0.46      1000

# %%
#Plot Descision Tree
dot_data = tree.export_graphviz(clf, out_file=None,
#                      feature_names=vectorizer.get_feature_names(),
                     class_names=["0", "1"],
                     filled=True, rounded=True,
                     special_characters=True)

dot_data = tree.export_graphviz(clf, out_file=None)
graph = graphviz.Source(dot_data)
graph.render("RandoredDT_After")
graph
